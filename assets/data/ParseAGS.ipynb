# %%
import pandas as pd
import os
import numpy as np

# %%
county_unemployment_file = os.path.join("AGS_data", "CO_UNEMP.csv")
countyUnemployment = pd.read_csv(county_unemployment_file)
countyUnemployment
# Out:
#          CO               NAME     LBF  UE19B  PU19B  UE07MAR  PU07MAR  \
# 0      1001     Autauga County   25819    673   2.61      690     2.67
# 1      1003     Baldwin County  102814   2688   2.61     2763     2.69
# 2      1005     Barbour County    9431    353   3.74      359     3.81
# 3      1007        Bibb County    8679    268   3.09      273     3.15
# 4      1009      Blount County   22196    580   2.61      593     2.67
# ...     ...                ...     ...    ...    ...      ...      ...
# 3137  56037  Sweetwater County   23394    785   3.36      821     3.51
# 3138  56039       Teton County   14991    569   3.80      601     4.01
# 3139  56041       Uinta County   10019    322   3.21      338     3.37
# 3140  56043    Washakie County    3888    176   4.53      181     4.66
# 3141  56045      Weston County    3397     76   2.24       80     2.36
#
#       UE14MAR  PU14MAR  UE21MAR  ...  UE18APR  PU18APR  UE25APR  PU25APR  \
# ...

# %%
exportDF = pd.DataFrame( columns = ["county_code","county_name", "labor_force", "file_week_ended", "percent_unemployed", "continued_claims"])

exportDF
# Out:
# Empty DataFrame
# Columns: [county_code, county_name, labor_force, file_week_ended, percent_unemployed, continued_claims]
# Index: []

# %%
newRows = []
for index, row in countyUnemployment.iterrows():
        
    myNewRow = {"county_code" : row["CO"],
                "county_name" : row["NAME"],
                "labor_force" : row["LBF"],
                "file_week_ended": "2020-03-07",
                "percent_unemployed": row["PU07MAR"],
                "total_unemployed": row["UE07MAR"]}
    
    newRows.append(myNewRow)

    myNewRow = {"county_code" : row["CO"],
                "county_name" : row["NAME"],
                "labor_force" : row["LBF"],
                "file_week_ended" : "2020-03-14",
                "percent_unemployed" : row["PU14MAR"],
                "total_unemployed" : row["UE14MAR"]}
    
    newRows.append(myNewRow)
                  
    myNewRow = {"county_code" : row["CO"],
                "county_name" : row["NAME"],
                "labor_force" : row["LBF"],
                "file_week_ended": "2020-03-21",
                "percent_unemployed": row["PU21MAR"],
                "total_unemployed" : row["UE21MAR"]}
    
    newRows.append(myNewRow)
                  
    myNewRow = {"county_code" : row["CO"],
                "county_name" : row["NAME"],
                "labor_force" : row["LBF"],
                "file_week_ended" : "2020-03-28",
                "percent_unemployed" : row["PU28MAR"],
                "total_unemployed" : row["UE28MAR"]}
    
    newRows.append(myNewRow)
                  
    myNewRow = {"county_code" : row["CO"],
                "county_name" : row["NAME"],
                "labor_force" : row["LBF"],
                "file_week_ended" : "2020-04-04",
                "percent_unemployed" : row["PU04APR"],
                "total_unemployed" : row["UE04APR"]}
    
    newRows.append(myNewRow)
                  
    myNewRow = {"county_code" : row["CO"],
                "county_name" : row["NAME"],
                "labor_force" : row["LBF"],
                "file_week_ended" : "2020-04-11",
                "percent_unemployed" : row["PU11APR"],
                "total_unemployed" : row["UE11APR"]}
    
    newRows.append(myNewRow)
                  
    myNewRow = {"county_code" : row["CO"],
                "county_name" : row["NAME"],
                "labor_force" : row["LBF"],
                "file_week_ended" : "2020-04-18",
                "percent_unemployed": row["PU18APR"],
                "total_unemployed" : row["UE18APR"]}
              
    newRows.append(myNewRow)

    myNewRow = {"county_code" : row["CO"],
                "county_name" : row["NAME"],
                "labor_force" : row["LBF"],
                "file_week_ended" : "2020-04-25",
                "percent_unemployed" : row["PU25APR"],
                "total_unemployed" : row["UE25APR"]}
    
    newRows.append(myNewRow)

    myNewRow = {"county_code" : row["CO"],
                "county_name" : row["NAME"],
                "labor_force" : row["LBF"],
                "file_week_ended": "2020-05-02",
                "percent_unemployed": row["PU02MAY"],
                "total_unemployed": row["UE02MAY"]}
              
    newRows.append(myNewRow)
    
    myNewRow = {"county_code" : row["CO"],
                "county_name" : row["NAME"],
                "labor_force" : row["LBF"],
                "file_week_ended": "2020-05-09",
                "percent_unemployed": row["PU09MAY"],
                "total_unemployed": row["UE09MAY"]}
              
    newRows.append(myNewRow)
    
    myNewRow = {"county_code" : row["CO"],
                "county_name" : row["NAME"],
                "labor_force" : row["LBF"],
                "file_week_ended": "2020-05-16",
                "percent_unemployed": row["PU16MAY"],
                "total_unemployed": row["UE16MAY"]}
              
    newRows.append(myNewRow)

# %%
exportDF = pd.DataFrame(newRows)

# %%
exportDF
# Out:
#        county_code     county_name  labor_force file_week_ended  \
# 0             1001  Autauga County        25819      2020-03-07
# 1             1001  Autauga County        25819      2020-03-14
# 2             1001  Autauga County        25819      2020-03-21
# 3             1001  Autauga County        25819      2020-03-28
# 4             1001  Autauga County        25819      2020-04-04
# ...            ...             ...          ...             ...
# 34557        56045   Weston County         3397      2020-04-18
# 34558        56045   Weston County         3397      2020-04-25
# 34559        56045   Weston County         3397      2020-05-02
# 34560        56045   Weston County         3397      2020-05-09
# 34561        56045   Weston County         3397      2020-05-16
#
#        percent_unemployed  total_unemployed
# 0                    2.67               690
# 1                    2.75               710
# 2                    3.21               828
# ...

# %%
exportDF["county_name"].unique()
# Out:
# array(['Autauga County', 'Baldwin County', 'Barbour County', ...,
#        'Uinta County', 'Washakie County', 'Weston County'], dtype=object)

# %%
exportDF['county_code'] = exportDF['county_code'].astype(str)

# %%
exportDF
# Out:
#       county_code     county_name  labor_force file_week_ended  \
# 0            1001  Autauga County        25819      2020-03-07
# 1            1001  Autauga County        25819      2020-03-14
# 2            1001  Autauga County        25819      2020-03-21
# 3            1001  Autauga County        25819      2020-03-28
# 4            1001  Autauga County        25819      2020-04-04
# ...           ...             ...          ...             ...
# 34557       56045   Weston County         3397      2020-04-18
# 34558       56045   Weston County         3397      2020-04-25
# 34559       56045   Weston County         3397      2020-05-02
# 34560       56045   Weston County         3397      2020-05-09
# 34561       56045   Weston County         3397      2020-05-16
#
#        percent_unemployed  total_unemployed
# 0                    2.67               690
# 1                    2.75               710
# 2                    3.21               828
# ...

# %%
for index, row in exportDF.iterrows():
    if len(row["county_code"]) == 4:
        exportDF.at[index, "county_code"] = "0" + row["county_code"]
# Out:
# 1001
# 1001
# 1001
# 1001
# 1001
# 1001
# 1001
# 1001
# 1001
# 1001
# 1001
# 1003
# 1003
# 1003
# 1003
# 1003
# 1003
# 1003
# 1003
# 1003
# 1003
# 1003
# 1005
# 1005
# 1005
# 1005
# 1005
# 1005
# 1005
# 1005
# 1005
# 1005
# 1005
# 1007
# 1007
# 1007
# 1007
# 1007
# 1007
# 1007
# 1007
# 1007
# 1007
# 1007
# 1009
# 1009
# 1009
# 1009
# 1009
# 1009
# 1009
# 1009
# 1009
# 1009
# 1009
# 1011
# 1011
# 1011
# 1011
# 1011
# 1011
# 1011
# 1011
# 1011
# 1011
# 1011
# 1013
# 1013
# 1013
# 1013
# 1013
# 1013
# 1013
# 1013
# 1013
# 1013
# 1013
# 1015
# 1015
# 1015
# 1015
# 1015
# 1015
# 1015
# 1015
# 1015
# 1015
# 1015
# 1017
# 1017
# 1017
# 1017
# 1017
# 1017
# 1017
# 1017
# 1017
# 1017
# 1017
# 1019
# 1019
# 1019
# 1019
# 1019
# 1019
# 1019
# 1019
# 1019
# 1019
# 1019
# 1021
# 1021
# 1021
# 1021
# 1021
# 1021
# 1021
# 1021
# 1021
# 1021
# 1021
# 1023
# 1023
# 1023
# 1023
# 1023
# 1023
# 1023
# 1023
# 1023
# 1023
# 1023
# 1025
# 1025
# 1025
# 1025
# 1025
# 1025
# 1025
# 1025
# 1025
# 1025
# ...

# %%
exportDF
# Out:
#       county_code     county_name  labor_force file_week_ended  \
# 0           01001  Autauga County        25819      2020-03-07
# 1           01001  Autauga County        25819      2020-03-14
# 2           01001  Autauga County        25819      2020-03-21
# 3           01001  Autauga County        25819      2020-03-28
# 4           01001  Autauga County        25819      2020-04-04
# ...           ...             ...          ...             ...
# 34557       56045   Weston County         3397      2020-04-18
# 34558       56045   Weston County         3397      2020-04-25
# 34559       56045   Weston County         3397      2020-05-02
# 34560       56045   Weston County         3397      2020-05-09
# 34561       56045   Weston County         3397      2020-05-16
#
#        percent_unemployed  total_unemployed
# 0                    2.67               690
# 1                    2.75               710
# 2                    3.21               828
# ...

# %%
exportDF.to_csv("AGS_Data_Massaged.csv", index=False)
