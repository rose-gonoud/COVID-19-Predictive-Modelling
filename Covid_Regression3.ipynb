# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import pandas as pd
import warnings
import statsmodels.formula.api as smf
warnings.simplefilter('ignore', FutureWarning)

# %%
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.2.4-tf'

# %%
pd.options.display.max_rows = 300

# %%
pd.options.display.max_columns = 200

# %%
# Read in CSV files
covid = pd.read_csv('../COVID-19-Predictive-Modelling/assets/data/COVID County Data/COVID_data_on_lockdown_plus_30.csv')
social = pd.read_csv('../COVID-19-Predictive-Modelling/assets/data/SVI2018_US_COUNTY_2.csv')
employment = pd.read_csv('../COVID-19-Predictive-Modelling/assets/data/AGS_data/AGS_Data_Massaged3.csv')

# %%
covid.dtypes
# Out:
# Unnamed: 0            int64
# name                 object
# date                 object
# fips                float64
# lat                 float64
# long                float64
# confirmed             int64
# deaths                int64
# confirmed_diff        int64
# deaths_diff           int64
# state                object
# state_abbr           object
# lockdown_date        object
# lockdown_plus_30     object
# dtype: object

# %%
covid.head()
# Out:
#    Unnamed: 0     name        date    fips        lat       long  confirmed  \
# 0        2808  Autauga  2020-05-03  1001.0  32.539527 -86.644082         48
# 1        2809  Baldwin  2020-05-03  1003.0  30.727750 -87.722071        187
# 2        2810  Barbour  2020-05-03  1005.0  31.868263 -85.387129         45
# 3        2811     Bibb  2020-05-03  1007.0  32.996421 -87.125115         43
# 4        2812   Blount  2020-05-03  1009.0  33.982109 -86.567906         40
#
#    deaths  confirmed_diff  deaths_diff    state state_abbr lockdown_date  \
# 0       3               3            0  Alabama         AL    2020-04-03
# 1       4               6            0  Alabama         AL    2020-04-03
# 2       1               2            0  Alabama         AL    2020-04-03
# 3       0               1            0  Alabama         AL    2020-04-03
# 4       0               0            0  Alabama         AL    2020-04-03
#
#   lockdown_plus_30
# 0       2020-05-03
# 1       2020-05-03
# 2       2020-05-03
# 3       2020-05-03
# 4       2020-05-03

# %%
covid.drop('Unnamed: 0', axis=1, inplace=True)
covid.head()
# Out:
#       name        date    fips        lat       long  confirmed  deaths  \
# 0  Autauga  2020-05-03  1001.0  32.539527 -86.644082         48       3
# 1  Baldwin  2020-05-03  1003.0  30.727750 -87.722071        187       4
# 2  Barbour  2020-05-03  1005.0  31.868263 -85.387129         45       1
# 3     Bibb  2020-05-03  1007.0  32.996421 -87.125115         43       0
# 4   Blount  2020-05-03  1009.0  33.982109 -86.567906         40       0
#
#    confirmed_diff  deaths_diff    state state_abbr lockdown_date  \
# 0               3            0  Alabama         AL    2020-04-03
# 1               6            0  Alabama         AL    2020-04-03
# 2               2            0  Alabama         AL    2020-04-03
# 3               1            0  Alabama         AL    2020-04-03
# 4               0            0  Alabama         AL    2020-04-03
#
#   lockdown_plus_30
# 0       2020-05-03
# 1       2020-05-03
# 2       2020-05-03
# 3       2020-05-03
# 4       2020-05-03

# %%
covid.fips = covid.fips.values.astype(float).astype(int).astype(str)
covid.head()
# Out:
#       name        date  fips        lat       long  confirmed  deaths  \
# 0  Autauga  2020-05-03  1001  32.539527 -86.644082         48       3
# 1  Baldwin  2020-05-03  1003  30.727750 -87.722071        187       4
# 2  Barbour  2020-05-03  1005  31.868263 -85.387129         45       1
# 3     Bibb  2020-05-03  1007  32.996421 -87.125115         43       0
# 4   Blount  2020-05-03  1009  33.982109 -86.567906         40       0
#
#    confirmed_diff  deaths_diff    state state_abbr lockdown_date  \
# 0               3            0  Alabama         AL    2020-04-03
# 1               6            0  Alabama         AL    2020-04-03
# 2               2            0  Alabama         AL    2020-04-03
# 3               1            0  Alabama         AL    2020-04-03
# 4               0            0  Alabama         AL    2020-04-03
#
#   lockdown_plus_30
# 0       2020-05-03
# 1       2020-05-03
# 2       2020-05-03
# 3       2020-05-03
# 4       2020-05-03

# %%
social.head()
# Out:
#    ST       STATE      COUNTY   fips    AREA_SQMI  E_TOTPOP   E_HU   E_HH  \
# 0  35  NEW MEXICO  Rio Arriba  35039  5860.869195     39307  20044  12398
# 1   1     ALABAMA     Autauga   1001   594.443459     55200  23315  21115
# 2   1     ALABAMA      Blount   1009   644.830460     57645  24222  20600
# 3   1     ALABAMA      Butler   1013   776.838201     20025  10026   6708
# 4   1     ALABAMA     Calhoun   1015   605.867251    115098  53682  45033
#
#    E_POV  E_UNEMP  E_PCI  E_NOHSDP  E_AGE65  E_AGE17  E_DISABL  E_SNGPNT  \
# 0   -999     -999   -999      3669     7083     9318      6280      1330
# 1   8422     1065  29372      4204     8050    13369     10465      1586
# 2   8220      909  22656      7861    10233    13468      8114      1437
# 3   4640      567  20430      2141     3806     4566      3492       704
# 4  20819     4628  24706     12620    19386    25196     23598      4701
#
#    E_MINRTY  E_LIMENG  E_MUNIT  E_MOBILE  E_CROWD  E_NOVEH  E_GROUPQ
# 0     34397       755       67      7770      264      763       654
# 1     13788       426      886      4279      299     1191       546
# 2      7413       934      211      6108      339      856       543
# 3      9641        93      134      2625      119      520       322
# 4     31675      1076     1990      7904      772     2599      3112

# %%
social.dtypes
# Out:
# ST             int64
# STATE         object
# COUNTY        object
# fips           int64
# AREA_SQMI    float64
# E_TOTPOP       int64
# E_HU           int64
# E_HH           int64
# E_POV          int64
# E_UNEMP        int64
# E_PCI          int64
# E_NOHSDP       int64
# E_AGE65        int64
# E_AGE17        int64
# E_DISABL       int64
# E_SNGPNT       int64
# E_MINRTY       int64
# E_LIMENG       int64
# E_MUNIT        int64
# E_MOBILE       int64
# E_CROWD        int64
# E_NOVEH        int64
# E_GROUPQ       int64
# dtype: object

# %%
social.fips = social.fips.values.astype(str)
social.dtypes
# Out:
# ST             int64
# STATE         object
# COUNTY        object
# fips          object
# AREA_SQMI    float64
# E_TOTPOP       int64
# E_HU           int64
# E_HH           int64
# E_POV          int64
# E_UNEMP        int64
# E_PCI          int64
# E_NOHSDP       int64
# E_AGE65        int64
# E_AGE17        int64
# E_DISABL       int64
# E_SNGPNT       int64
# E_MINRTY       int64
# E_LIMENG       int64
# E_MUNIT        int64
# E_MOBILE       int64
# E_CROWD        int64
# E_NOVEH        int64
# E_GROUPQ       int64
# dtype: object

# %%
employment.head()
# Out:
#    county_code     county_name  labor_force file_week_ended  \
# 0         1001  Autauga County        25819      2020-03-07
# 1         1001  Autauga County        25819      2020-03-14
# 2         1001  Autauga County        25819      2020-03-21
# 3         1001  Autauga County        25819      2020-03-28
# 4         1001  Autauga County        25819      2020-04-04
#
#    percent_unemployed  total_unemployed
# 0                2.67               690
# 1                2.75               710
# 2                3.21               828
# 3                6.60              1703
# 4               11.07              2857

# %%
employment.dtypes
# Out:
# county_code             int64
# county_name            object
# labor_force             int64
# file_week_ended        object
# percent_unemployed    float64
# total_unemployed        int64
# dtype: object

# %%
employment = employment.rename(columns={'county_code': 'fips'})

# %%
employment.fips = employment.fips.values.astype(str)
employment.dtypes
# Out:
# fips                   object
# county_name            object
# labor_force             int64
# file_week_ended        object
# percent_unemployed    float64
# total_unemployed        int64
# dtype: object

# %%
# For the SVI, -999 reflects missing values. Apparantly, only one county has -999 vaules in their dataset, so removing.
social =  social[(social.iloc[:, 1:] != -999).all(axis=1)]
social.head()
# Out:
#    ST    STATE    COUNTY  fips   AREA_SQMI  E_TOTPOP   E_HU   E_HH  E_POV  \
# 1   1  ALABAMA   Autauga  1001  594.443459     55200  23315  21115   8422
# 2   1  ALABAMA    Blount  1009  644.830460     57645  24222  20600   8220
# 3   1  ALABAMA    Butler  1013  776.838201     20025  10026   6708   4640
# 4   1  ALABAMA   Calhoun  1015  605.867251    115098  53682  45033  20819
# 5   1  ALABAMA  Chambers  1017  596.560643     33826  16981  13516   5531
#
#    E_UNEMP  E_PCI  E_NOHSDP  E_AGE65  E_AGE17  E_DISABL  E_SNGPNT  E_MINRTY  \
# 1     1065  29372      4204     8050    13369     10465      1586     13788
# 2      909  22656      7861    10233    13468      8114      1437      7413
# 3      567  20430      2141     3806     4566      3492       704      9641
# 4     4628  24706     12620    19386    25196     23598      4701     31675
# 5      773  22827      4383     6409     7006      5570      1307     14954
#
#    E_LIMENG  E_MUNIT  E_MOBILE  E_CROWD  E_NOVEH  E_GROUPQ
# 1       426      886      4279      299     1191       546
# 2       934      211      6108      339      856       543
# 3        93      134      2625      119      520       322
# 4      1076     1990      7904      772     2599      3112
# 5        36      679      2378      404      989       512

# %%
# Merge covid and social on fips
covsoc = pd.merge(covid, social, on='fips')
covsoc.head()
# Out:
#       name        date  fips        lat       long  confirmed  deaths  \
# 0  Autauga  2020-05-03  1001  32.539527 -86.644082         48       3
# 1  Baldwin  2020-05-03  1003  30.727750 -87.722071        187       4
# 2  Barbour  2020-05-03  1005  31.868263 -85.387129         45       1
# 3     Bibb  2020-05-03  1007  32.996421 -87.125115         43       0
# 4   Blount  2020-05-03  1009  33.982109 -86.567906         40       0
#
#    confirmed_diff  deaths_diff    state state_abbr lockdown_date  \
# 0               3            0  Alabama         AL    2020-04-03
# 1               6            0  Alabama         AL    2020-04-03
# 2               2            0  Alabama         AL    2020-04-03
# 3               1            0  Alabama         AL    2020-04-03
# 4               0            0  Alabama         AL    2020-04-03
#
#   lockdown_plus_30  ST    STATE   COUNTY    AREA_SQMI  E_TOTPOP    E_HU  \
# 0       2020-05-03   1  ALABAMA  Autauga   594.443459     55200   23315
# 1       2020-05-03   1  ALABAMA  Baldwin  1589.793007    208107  111945
# 2       2020-05-03   1  ALABAMA  Barbour   885.001636     25782   11937
# 3       2020-05-03   1  ALABAMA     Bibb   622.461089     22527    9161
# 4       2020-05-03   1  ALABAMA   Blount   644.830460     57645   24222
#
#     E_HH  E_POV  E_UNEMP  E_PCI  E_NOHSDP  E_AGE65  E_AGE17  E_DISABL  \
# 0  21115   8422     1065  29372      4204     8050    13369     10465
# 1  78622  21653     4343  31203     14310    40665    45677     28863
# 2   9186   6597      918  18461      4901     4634     5436      5078
# 3   6840   2863      658  20199      2650     3661     4659      3412
# 4  20600   8220      909  22656      7861    10233    13468      8114
#
#    E_SNGPNT  E_MINRTY  E_LIMENG  E_MUNIT  E_MOBILE  E_CROWD  E_NOVEH  E_GROUPQ
# 0      1586     13788       426      886      4279      299     1191       546
# 1      4508     35339      1068    20492     13075      991     2705      3014
# 2      1174     13884       398      152      3484      313      849      2900
# 3       407      5726        57      222      2615       52      410      2091
# 4      1437      7413       934      211      6108      339      856       543

# %%
covsoc.shape
# Out:
# (2518, 35)

# %%
# Note that total population in these calculations is from the SVI, which was conducted 2014-2018. So, it's not the current number, but an approximation. 
covsoc['percent_confirmed'] = ((covsoc['confirmed'] / covsoc['E_TOTPOP'].sum())*100).round(10).astype(str)

# %%
covsoc['percent_deaths'] = ((covsoc['deaths'] / covsoc['E_TOTPOP'].sum())*100).round(10).astype(str)

# %%
covsoc.head()
# Out:
#       name        date  fips        lat       long  confirmed  deaths  \
# 0  Autauga  2020-05-03  1001  32.539527 -86.644082         48       3
# 1  Baldwin  2020-05-03  1003  30.727750 -87.722071        187       4
# 2  Barbour  2020-05-03  1005  31.868263 -85.387129         45       1
# 3     Bibb  2020-05-03  1007  32.996421 -87.125115         43       0
# 4   Blount  2020-05-03  1009  33.982109 -86.567906         40       0
#
#    confirmed_diff  deaths_diff    state state_abbr lockdown_date  \
# 0               3            0  Alabama         AL    2020-04-03
# 1               6            0  Alabama         AL    2020-04-03
# 2               2            0  Alabama         AL    2020-04-03
# 3               1            0  Alabama         AL    2020-04-03
# 4               0            0  Alabama         AL    2020-04-03
#
#   lockdown_plus_30  ST    STATE   COUNTY    AREA_SQMI  E_TOTPOP    E_HU  \
# 0       2020-05-03   1  ALABAMA  Autauga   594.443459     55200   23315
# 1       2020-05-03   1  ALABAMA  Baldwin  1589.793007    208107  111945
# 2       2020-05-03   1  ALABAMA  Barbour   885.001636     25782   11937
# 3       2020-05-03   1  ALABAMA     Bibb   622.461089     22527    9161
# 4       2020-05-03   1  ALABAMA   Blount   644.830460     57645   24222
#
#     E_HH  E_POV  E_UNEMP  E_PCI  E_NOHSDP  E_AGE65  E_AGE17  E_DISABL  \
# 0  21115   8422     1065  29372      4204     8050    13369     10465
# 1  78622  21653     4343  31203     14310    40665    45677     28863
# 2   9186   6597      918  18461      4901     4634     5436      5078
# 3   6840   2863      658  20199      2650     3661     4659      3412
# 4  20600   8220      909  22656      7861    10233    13468      8114
#
#    E_SNGPNT  E_MINRTY  E_LIMENG  E_MUNIT  E_MOBILE  E_CROWD  E_NOVEH  \
# 0      1586     13788       426      886      4279      299     1191
# 1      4508     35339      1068    20492     13075      991     2705
# 2      1174     13884       398      152      3484      313      849
# 3       407      5726        57      222      2615       52      410
# 4      1437      7413       934      211      6108      339      856
#
#    E_GROUPQ percent_confirmed percent_deaths
# 0       546       1.58297e-05      9.894e-07
# 1      3014       6.16697e-05     1.3191e-06
# 2      2900       1.48403e-05      3.298e-07
# 3      2091       1.41807e-05            0.0
# 4       543       1.31914e-05            0.0

# %%
covsoc.to_csv('../covsoc.csv')

# %%
# Model 1: Linear regression predicting confirmed (summed count) from SVI
X = covsoc[['AREA_SQMI','E_HU', 'E_HH', 'E_POV', 'E_UNEMP', 'E_PCI', 'E_NOHSDP', 'E_AGE65', 'E_AGE17', 'E_DISABL', 'E_SNGPNT', 'E_MINRTY', 'E_LIMENG', 'E_MUNIT', 'E_MOBILE', 'E_CROWD', 'E_NOVEH', 'E_GROUPQ']]

# %%
Y = covsoc['confirmed'].values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
score = model.score(X, Y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.8801289785774624

# %%
model = smf.ols(formula='Y ~ X', data=covsoc)

# %%
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     1019.
# Date:                Sat, 30 May 2020   Prob (F-statistic):               0.00
# Time:                        15:57:27   Log-Likelihood:                -21149.
# No. Observations:                2518   AIC:                         4.234e+04
# Df Residuals:                    2499   BIC:                         4.245e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -221.8443    109.396     -2.028      0.043    -436.360      -7.329
# X[0]          -0.0006      0.006     -0.085      0.932      -0.013       0.012
# X[1]          -0.0090      0.006     -1.605      0.109      -0.020       0.002
# X[2]          -0.0795      0.006    -14.178      0.000      -0.090      -0.068
# X[3]          -0.0489      0.005    -10.214      0.000      -0.058      -0.040
# X[4]          -0.1403      0.017     -8.472      0.000      -0.173      -0.108
# X[5]           0.0092      0.004      2.262      0.024       0.001       0.017
# X[6]           0.0326      0.008      4.235      0.000       0.018       0.048
# X[7]           0.0775      0.005     15.268      0.000       0.068       0.088
# X[8]           0.0969      0.003     30.440      0.000       0.091       0.103
# X[9]           0.0127      0.007      1.703      0.089      -0.002       0.027
# X[10]          0.0568      0.024      2.330      0.020       0.009       0.105
# X[11]         -0.0073      0.001     -7.695      0.000      -0.009      -0.005
# X[12]         -0.0085      0.005     -1.674      0.094      -0.018       0.001
# X[13]          0.0560      0.004     14.174      0.000       0.048       0.064
# X[14]         -0.0136      0.007     -1.846      0.065      -0.028       0.001
# X[15]         -0.0687      0.017     -4.011      0.000      -0.102      -0.035
# X[16]          0.2209      0.004     49.805      0.000       0.212       0.230
# X[17]          0.0553      0.008      7.286      0.000       0.040       0.070
# ==============================================================================
# Omnibus:                     2734.992   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2131607.031
# Skew:                           4.550   Prob(JB):                         0.00
# Kurtosis:                     145.247   Cond. No.                     1.67e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Model 2: Linear regression predicting confirmed_percentage (percentage from total population) from SVI
X2 = covsoc[['AREA_SQMI', 'E_HU', 'E_HH', 'E_POV', 'E_UNEMP', 'E_PCI', 'E_NOHSDP', 'E_AGE65', 'E_AGE17', 'E_DISABL', 'E_SNGPNT', 'E_MINRTY', 'E_LIMENG', 'E_MUNIT', 'E_MOBILE', 'E_CROWD', 'E_NOVEH', 'E_GROUPQ']]

# %%
Y2 = covsoc['percent_confirmed'].values.reshape(-1,1)

# %%
model2 = LinearRegression()

# %%
model2.fit(X2, Y2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
score = model2.score(X2, Y2)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.8801289788154453

# %%
# Model 3: Linear regression predicting deaths from SVI
X3 = covsoc[['AREA_SQMI', 'E_HU', 'E_HH', 'E_POV', 'E_UNEMP', 'E_PCI', 'E_NOHSDP', 'E_AGE65', 'E_AGE17', 'E_DISABL', 'E_SNGPNT', 'E_MINRTY', 'E_LIMENG', 'E_MUNIT', 'E_MOBILE', 'E_CROWD', 'E_NOVEH', 'E_GROUPQ']]

# %%
Y3 = covsoc['deaths'].values.reshape(-1,1)

# %%
model3 = LinearRegression()

# %%
model3.fit(X3, Y3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
score = model3.score(X3, Y3)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.9111858810765072

# %%
model3 = smf.ols(formula='Y3 ~ X3', data=covsoc)

# %%
results = model3.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     Y3   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     1424.
# Date:                Sat, 30 May 2020   Prob (F-statistic):               0.00
# Time:                        16:01:25   Log-Likelihood:                -14842.
# No. Observations:                2518   AIC:                         2.972e+04
# Df Residuals:                    2499   BIC:                         2.983e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -34.2620      8.936     -3.834      0.000     -51.784     -16.740
# X3[0]       9.238e-05      0.001      0.175      0.861      -0.001       0.001
# X3[1]         -0.0024      0.000     -5.215      0.000      -0.003      -0.001
# X3[2]         -0.0070      0.000    -15.300      0.000      -0.008      -0.006
# X3[3]         -0.0036      0.000     -9.202      0.000      -0.004      -0.003
# X3[4]         -0.0139      0.001    -10.297      0.000      -0.017      -0.011
# X3[5]          0.0014      0.000      4.186      0.000       0.001       0.002
# X3[6]          0.0006      0.001      1.016      0.309      -0.001       0.002
# X3[7]          0.0060      0.000     14.419      0.000       0.005       0.007
# X3[8]          0.0090      0.000     34.453      0.000       0.008       0.009
# X3[9]          0.0034      0.001      5.554      0.000       0.002       0.005
# X3[10]         0.0113      0.002      5.650      0.000       0.007       0.015
# X3[11]        -0.0009   7.77e-05    -11.860      0.000      -0.001      -0.001
# X3[12]        -0.0030      0.000     -7.291      0.000      -0.004      -0.002
# X3[13]         0.0084      0.000     26.031      0.000       0.008       0.009
# X3[14]         0.0038      0.001      6.339      0.000       0.003       0.005
# X3[15]         0.0090      0.001      6.402      0.000       0.006       0.012
# X3[16]         0.0201      0.000     55.374      0.000       0.019       0.021
# X3[17]         0.0020      0.001      3.270      0.001       0.001       0.003
# ==============================================================================
# Omnibus:                     1014.405   Durbin-Watson:                   1.814
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           897851.449
# Skew:                          -0.224   Prob(JB):                         0.00
# Kurtosis:                      95.507   Cond. No.                     1.67e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Model 3: Linear regression predicting percent_deaths from SVI
X4 = covsoc[['AREA_SQMI', 'E_HU', 'E_HH', 'E_POV', 'E_UNEMP', 'E_PCI', 'E_NOHSDP', 'E_AGE65', 'E_AGE17', 'E_DISABL', 'E_SNGPNT', 'E_MINRTY', 'E_LIMENG', 'E_MUNIT', 'E_MOBILE', 'E_CROWD', 'E_NOVEH', 'E_GROUPQ']]

# %%
Y4 = covsoc['percent_deaths'].values.reshape(-1,1)

# %%
model4 = LinearRegression()

# %%
model4.fit(X4, Y4)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
score = model4.score(X4, Y4)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.9111858805398244

# %%
# Pearson correlation matrix
import seaborn as sns
plt.figure(figsize=(16,12))
cor = covsoc.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()
